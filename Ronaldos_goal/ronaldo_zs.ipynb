# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## <font color=green>reading data</font>

# %%
raw_df=pd.read_csv('data.csv')
raw_df.shape
# Out:
# (30697, 28)

# %%
pd.options.display.max_columns=None
raw_df
# Out:
#        Unnamed: 0  match_event_id  location_x  location_y  remaining_min  \
# 0               0            10.0       167.0        72.0           10.0
# 1               1            12.0      -157.0         0.0           10.0
# 2               2            35.0      -101.0       135.0            7.0
# 3               3            43.0       138.0       175.0            6.0
# 4               4           155.0         0.0         0.0            NaN
# 5               5           244.0      -145.0       -11.0            9.0
# 6               6           251.0         0.0         0.0            8.0
# 7               7           254.0         1.0        28.0            8.0
# 8               8           265.0       -65.0         NaN            6.0
# 9               9           294.0       -33.0         NaN            3.0
# 10             10           309.0       -94.0       238.0            1.0
# 11             11             4.0       121.0       127.0           11.0
# ...

# %%
raw_df['lat/lng'].unique()
# Out:
# array(['45.539131, -122.651648', '42.982923, -71.446094',
#        '49.250068, -123.114646', nan, '29.740325, -95.365762',
#        '29.444994, -98.524120', '38.567296, -121.456638',
#        '39.739968, -104.954013', '34.189593, -118.471724',
#        '47.633181, -122.308343', '37.754130, -122.437947',
#        '43.717098, -79.395917', '25.790710, -80.207819',
#        '32.757824, -96.786653', '33.552026, -112.071667',
#        '40.774891, -111.930790', '40.708999, -73.872430',
#        '41.484971, -81.671552', '46.667324, -94.419250',
#        '40.643505, -73.939507', '39.993941, -75.143458',
#        '35.205878, -80.841194', '40.361408, -86.186052',
#        '42.379455, -83.115635', '38.919619, -77.015211',
#        '28.549237, -81.372780', '33.768092, -84.393817',
#        '43.062206, -87.944754', '35.103812, -89.964007',
#        '41.845137, -87.660450', '42.330507, -71.074655',
#        '30.018061, -90.022651', '40.324211, -111.674849',
# ...

# %%
new=df.groupby(['match_id','home/away','lat/lng'])['is_goal'].mean()
new
# Out:
# match_id  home/away     lat/lng
# 20000012  MANU @ POR    45.539131, -122.651648    0.428571
# 20000019  MANU vs. UTA  42.982923, -71.446094     0.388889
# 20000047  MANU @ VAN    49.250068, -123.114646    0.555556
# 20000049  MANU vs. LAC  42.982923, -71.446094     0.333333
# 20000058  MANU @ HOU    29.740325, -95.365762     0.363636
# 20000068  MANU @ SAS    29.444994, -98.524120     0.380952
# 20000098  MANU vs. HOU  42.982923, -71.446094     0.562500
# 20000108  MANU vs. DEN  42.982923, -71.446094     0.466667
# 20000124  MANU @ SAC    38.567296, -121.456638    0.350000
# 20000140  MANU @ DEN    39.739968, -104.954013    0.437500
# 20000147  MANU vs. CHI  42.982923, -71.446094     0.300000
# 20000168  MANU vs. GSW  42.982923, -71.446094     0.733333
# 20000180  MANU vs. MIN  42.982923, -71.446094     0.733333
# 20000198  MANU @ LAC    34.189593, -118.471724    0.615385
# 20000206  MANU vs. IND  42.982923, -71.446094     0.437500
# ...

# %%
raw_df.drop(['Unnamed: 0'],axis=1,inplace=True)
raw_df.columns
# Out:
# Index(['match_event_id', 'location_x', 'location_y', 'remaining_min',
#        'power_of_shot', 'knockout_match', 'game_season', 'remaining_sec',
#        'distance_of_shot', 'is_goal', 'area_of_shot', 'shot_basics',
#        'range_of_shot', 'team_name', 'date_of_game', 'home/away',
#        'shot_id_number', 'lat/lng', 'type_of_shot', 'type_of_combined_shot',
#        'match_id', 'team_id', 'remaining_min.1', 'power_of_shot.1',
#        'knockout_match.1', 'remaining_sec.1', 'distance_of_shot.1'],
#       dtype='object')

# %% [markdown]
# # checking number null values

# %%
raw_df.isnull().sum()
# Out:
# match_event_id            1563
# location_x                1461
# location_y                1540
# remaining_min             1562
# power_of_shot             1486
# knockout_match            1517
# game_season               5862
# remaining_sec             1594
# distance_of_shot          1567
# is_goal                   6268
# area_of_shot              1502
# shot_basics               1575
# range_of_shot             1564
# team_name                 1535
# date_of_game              1550
# home/away                 1497
# shot_id_number            1563
# lat/lng                   1565
# type_of_shot             15280
# type_of_combined_shot    15417
# match_id                     0
# team_id                      0
# remaining_min.1           1535
# power_of_shot.1           1539
# knockout_match.1          1493
# remaining_sec.1           1539
# distance_of_shot.1        1568
# dtype: int64

# %%
raw_df[['power_of_shot','power_of_shot.1']]

# %%
raw_df[raw_df['power_of_shot'].isnull()]

# %%
df=raw_df.copy()
df.columns.values
# Out:
# array(['match_event_id', 'location_x', 'location_y', 'remaining_min',
#        'power_of_shot', 'knockout_match', 'game_season', 'remaining_sec',
#        'distance_of_shot', 'is_goal', 'area_of_shot', 'shot_basics',
#        'range_of_shot', 'team_name', 'date_of_game', 'home/away',
#        'shot_id_number', 'lat/lng', 'type_of_shot',
#        'type_of_combined_shot', 'match_id', 'team_id', 'remaining_min.1',
#        'power_of_shot.1', 'knockout_match.1', 'remaining_sec.1',
#        'distance_of_shot.1'], dtype=object)

# %%
df['team_name'].unique()
# Out:
# array(['Manchester United', nan], dtype=object)

# %%
df_exp=df.drop(['remaining_min.1',
       'power_of_shot.1', 'knockout_match.1', 'remaining_sec.1',
       'distance_of_shot.1','team_name','shot_id_number','team_id'],axis=1)
df_exp
# Out:
#        match_event_id  location_x  location_y  remaining_min  power_of_shot  \
# 0                10.0       167.0        72.0           10.0            1.0
# 1                12.0      -157.0         0.0           10.0            1.0
# 2                35.0      -101.0       135.0            7.0            1.0
# 3                43.0       138.0       175.0            6.0            1.0
# 4               155.0         0.0         0.0            NaN            2.0
# 5               244.0      -145.0       -11.0            9.0            3.0
# 6               251.0         0.0         0.0            8.0            NaN
# 7               254.0         1.0        28.0            8.0            3.0
# 8               265.0       -65.0         NaN            6.0            3.0
# 9               294.0       -33.0         NaN            3.0            3.0
# 10              309.0       -94.0       238.0            1.0            3.0
# ...

# %%
df_exp.columns.values
# Out:
# array(['match_event_id', 'location_x', 'location_y', 'remaining_min',
#        'power_of_shot', 'knockout_match', 'game_season', 'remaining_sec',
#        'distance_of_shot', 'is_goal', 'area_of_shot', 'shot_basics',
#        'range_of_shot', 'date_of_game', 'home/away', 'lat/lng',
#        'type_of_shot', 'type_of_combined_shot', 'match_id'], dtype=object)

# %%
df_exp.drop(['home/away','lat/lng'],axis=1,inplace=True)
df_exp.columns.values
# Out:
# array(['match_event_id', 'location_x', 'location_y', 'remaining_min',
#        'power_of_shot', 'knockout_match', 'game_season', 'remaining_sec',
#        'distance_of_shot', 'is_goal', 'area_of_shot', 'shot_basics',
#        'range_of_shot', 'date_of_game', 'type_of_shot',
#        'type_of_combined_shot', 'match_id'], dtype=object)

# %%
int(df_exp['remaining_min'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-eb07fa046e7a> in <module>
# ----> 1 long(df_exp['remaining_min'].mean())
#
# NameError: name 'long' is not defined

# %%
df_exp[['power_of_shot','is_goal']].groupby(['power_of_shot'],as_index=False).mean()
# Out:
#    power_of_shot   is_goal
# 0            1.0  0.465864
# 1            2.0  0.448506
# 2            3.0  0.452902
# 3            4.0  0.410617
# 4            5.0  0.443137
# 5            6.0  0.407407
# 6            7.0  0.428571

# %%
df_exp[['area_of_shot','is_goal']].groupby(['area_of_shot'],as_index=False).mean()
# Out:
#             area_of_shot   is_goal
# 0              Center(C)  0.524320
# 1   Left Side Center(LC)  0.363576
# 2           Left Side(L)  0.392556
# 3         Mid Ground(MG)  0.014085
# 4  Right Side Center(RC)  0.382743
# 5          Right Side(R)  0.396975

# %% [markdown]
# ### almost zero goals from MG

# %%
df_exp[['range_of_shot','is_goal']].groupby(['range_of_shot'],as_index=False).mean()
# Out:
#      range_of_shot   is_goal
# 0        16-24 ft.  0.400643
# 1          24+ ft.  0.331720
# 2         8-16 ft.  0.435185
# 3  Back Court Shot  0.014286
# 4  Less Than 8 ft.  0.573896

# %% [markdown]
# ### almost zero goals from back court shot

# %%
df_exp[['knockout_match','is_goal']].groupby(['knockout_match'],as_index=False).mean()
# Out:
#    knockout_match   is_goal
# 0             0.0  0.444136
# 1             1.0  0.445758

# %% [markdown]
# ## to_datetime

# %%
df_exp['date_of_game']=pd.to_datetime(df_exp['date_of_game'])
df_exp['date_of_game']=pd.to_datetime(df_exp['date_of_game'],format='%d%m%y')

# %%
df_exp['month']=df_exp['date_of_game'].map(lambda x: x.month)
df_exp['year']=df_exp['date_of_game'].map(lambda x: x.year)
df_exp.drop(['date_of_game'],axis=1,inplace=True)

# %%
np.set_printoptions(threshold=np.inf)
df_exp['match_id'].value_counts()
# Out:
# 21501228    50
# 20200069    47
# 20500591    46
# 20600431    45
# 20700553    44
# 20601081    44
# 21200398    41
# 20500480    41
# 20200743    41
# 20200127    40
# 20600977    39
# 20500988    39
# 20501078    38
# 40200221    38
# 20800884    38
# 20600340    38
# 20200769    38
# 20601016    37
# 20701082    37
# 20900527    37
# 20500412    37
# 21400056    37
# 20200142    37
# 20500192    36
# 20500114    36
# 20000267    35
# 40500156    35
# 20200223    35
# 40000069    35
# 20500563    35
#             ..
# 29600727     3
# 29600044     3
# 29600072     3
# 29600488     3
# 49900084     3
# 49700059     3
# 49600013     3
# 29600991     3
# 29600432     3
# 49700075     2
# 29600086     2
# 29600844     2
# 21500906     2
# 29600219     2
# 29600136     2
# 29600382     2
# 29600781     2
# 29600095     2
# 20400518     2
# 49600008     1
# 29600767     1
# 29600031     1
# 29600961     1
# 29600202     1
# 49600044     1
# 29600284     1
# 29700933     1
# ...

# %%
df_exp
# Out:
#        match_event_id  location_x  location_y  remaining_min  power_of_shot  \
# 0                10.0       167.0        72.0           10.0            1.0
# 1                12.0      -157.0         0.0           10.0            1.0
# 2                35.0      -101.0       135.0            7.0            1.0
# 3                43.0       138.0       175.0            6.0            1.0
# 4               155.0         0.0         0.0            NaN            2.0
# 5               244.0      -145.0       -11.0            9.0            3.0
# 6               251.0         0.0         0.0            8.0            NaN
# 7               254.0         1.0        28.0            8.0            3.0
# 8               265.0       -65.0         NaN            6.0            3.0
# 9               294.0       -33.0         NaN            3.0            3.0
# 10              309.0       -94.0       238.0            1.0            3.0
# ...

# %%
#df['area_of_shot'].value_counts()
df_exp['remaining_min'].value_counts()
#df['shot_basics'].isnull().sum()
# Out:
# 0.0     3681
# 4.0     2709
# 3.0     2698
# 2.0     2688
# 1.0     2600
# 5.0     2508
# 6.0     2256
# 7.0     2094
# 9.0     2089
# 8.0     2028
# 10.0    2016
# 11.0    1768
# Name: remaining_min, dtype: int64

# %%
df_exp['remaining_min'].fillna(5,inplace=True)
df_exp['remaining_sec'].fillna(28,inplace=True)
df_exp['location_x'].fillna(df_exp['location_x'].mean(),inplace=True)
df_exp['location_y'].fillna(df_exp['location_y'].mean(),inplace=True)

# %%
df_exp
# Out:
#        match_event_id  location_x  location_y  remaining_min  power_of_shot  \
# 0                10.0  167.000000   72.000000           10.0            1.0
# 1                12.0 -157.000000    0.000000           10.0            1.0
# 2                35.0 -101.000000  135.000000            7.0            1.0
# 3                43.0  138.000000  175.000000            6.0            1.0
# 4               155.0    0.000000    0.000000            5.0            2.0
# 5               244.0 -145.000000  -11.000000            9.0            3.0
# 6               251.0    0.000000    0.000000            8.0            NaN
# 7               254.0    1.000000   28.000000            8.0            3.0
# 8               265.0  -65.000000   91.126933            6.0            3.0
# 9               294.0  -33.000000   91.126933            3.0            3.0
# 10              309.0  -94.000000  238.000000            1.0            3.0
# ...

# %%
df_exp['area_of_shot'].fillna('Center(C)',inplace=True)
# df_exp['area_of_shot'].isnull().sum()
df_exp['shot_basics'].fillna('Mid Range',inplace=True)
#df_exp['shot_basics'].isnull().sum()

# %%
pd.unique(df[['area_of_shot', 'range_of_shot']].values.ravel('K'))

# %%
from sklearn.preprocessing import LabelEncoder
encoder_shotbasics=LabelEncoder()
encoder_area=LabelEncoder()

num1=df_exp.columns.get_loc('shot_basics')
num2=df_exp.columns.get_loc('area_of_shot')
df_exp.iloc[:,num1]=encoder_shotbasics.fit_transform(df_exp.iloc[:,num1])
df_exp.iloc[:,num2]=encoder_area.fit_transform(df_exp.iloc[:,num2])

# %%
df_exp
# Out:
#        match_event_id  location_x  location_y  remaining_min  power_of_shot  \
# 0                10.0  167.000000   72.000000           10.0            1.0
# 1                12.0 -157.000000    0.000000           10.0            1.0
# 2                35.0 -101.000000  135.000000            7.0            1.0
# 3                43.0  138.000000  175.000000            6.0            1.0
# 4               155.0    0.000000    0.000000            5.0            2.0
# 5               244.0 -145.000000  -11.000000            9.0            3.0
# 6               251.0    0.000000    0.000000            8.0            NaN
# 7               254.0    1.000000   28.000000            8.0            3.0
# 8               265.0  -65.000000   91.126933            6.0            3.0
# 9               294.0  -33.000000   91.126933            3.0            3.0
# 10              309.0  -94.000000  238.000000            1.0            3.0
# ...

# %%
df_exp=df_exp.drop(['game_season','match_event_id'],axis=1)

# %%
df_exp
# Out:
#        location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 0      167.000000   72.000000           10.0            1.0             0.0
# 1     -157.000000    0.000000           10.0            1.0             0.0
# 2     -101.000000  135.000000            7.0            1.0             0.0
# 3      138.000000  175.000000            6.0            1.0             0.0
# 4        0.000000    0.000000            5.0            2.0             0.0
# 5     -145.000000  -11.000000            9.0            3.0             0.0
# 6        0.000000    0.000000            8.0            NaN             0.0
# 7        1.000000   28.000000            8.0            3.0             0.0
# 8      -65.000000   91.126933            6.0            3.0             0.0
# 9      -33.000000   91.126933            3.0            3.0             0.0
# 10     -94.000000  238.000000            1.0            3.0             0.0
# ...

# %%
df_exp.columns.values
# Out:
# array(['location_x', 'location_y', 'remaining_min', 'power_of_shot',
#        'knockout_match', 'remaining_sec', 'distance_of_shot', 'is_goal',
#        'area_of_shot', 'shot_basics', 'range_of_shot', 'type_of_shot',
#        'type_of_combined_shot', 'match_id', 'month', 'year'], dtype=object)

# %%
df_exp['month'].value_counts()
# Out:
# 3.0     4878
# 12.0    4706
# 1.0     4419
# 11.0    4025
# 2.0     3871
# 4.0     3608
# 5.0     2424
# 6.0      843
# 10.0     373
# Name: month, dtype: int64

# %%
df_exp['knockout_match'].fillna(0,inplace=True)
df_exp['distance_of_shot'].fillna(df_exp['distance_of_shot'].mean(),inplace=True)
df_exp['range_of_shot'].fillna('Less Than 8 ft.',inplace=True)
df_exp['shot_basics'].fillna(4,inplace=True)
df_exp['type_of_shot'].fillna(df_exp['type_of_combined_shot'],inplace=True)
df_exp.drop(['type_of_combined_shot'],axis=1,inplace=True)
df_exp['year'].fillna(2006,inplace=True)
df_exp['month'].fillna(5,inplace=True)

# %%
df_exp['power_of_shot'].fillna(3,inplace=True)

# %%
df_exp
# Out:
#        location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 0      167.000000   72.000000           10.0            1.0             0.0
# 1     -157.000000    0.000000           10.0            1.0             0.0
# 2     -101.000000  135.000000            7.0            1.0             0.0
# 3      138.000000  175.000000            6.0            1.0             0.0
# 4        0.000000    0.000000            5.0            2.0             0.0
# 5     -145.000000  -11.000000            9.0            3.0             0.0
# 6        0.000000    0.000000            8.0            3.0             0.0
# 7        1.000000   28.000000            8.0            3.0             0.0
# 8      -65.000000   91.126933            6.0            3.0             0.0
# 9      -33.000000   91.126933            3.0            3.0             0.0
# 10     -94.000000  238.000000            1.0            3.0             0.0
# ...

# %%
encoder_shot=LabelEncoder()
encoder_range=LabelEncoder()
num3=df_exp.columns.get_loc('type_of_shot')
num4=df_exp.columns.get_loc('range_of_shot')
df_exp.iloc[:,num3]=encoder_shot.fit_transform(df_exp.iloc[:,num3])
df_exp.iloc[:,num4]=encoder_range.fit_transform(df_exp.iloc[:,num4])

# %%
# df_exp1=df_exp['location_x', 'location_y', 'remaining_min', 'power_of_shot',
#        'knockout_match', 'remaining_sec', 'distance_of_shot',
#        'area_of_shot', 'shot_basics', 'range_of_shot', 'type_of_shot',
#        'match_id', 'month', 'year','is_goal']

df_exp=df_exp[['location_x', 'location_y', 'remaining_min', 'power_of_shot',
       'knockout_match', 'remaining_sec', 'distance_of_shot',
       'area_of_shot', 'shot_basics', 'range_of_shot', 'type_of_shot',
       'match_id', 'month', 'year','is_goal']]
df_exp
# Out:
#        location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 0      167.000000   72.000000           10.0            1.0             0.0
# 1     -157.000000    0.000000           10.0            1.0             0.0
# 2     -101.000000  135.000000            7.0            1.0             0.0
# 3      138.000000  175.000000            6.0            1.0             0.0
# 4        0.000000    0.000000            5.0            2.0             0.0
# 5     -145.000000  -11.000000            9.0            3.0             0.0
# 6        0.000000    0.000000            8.0            3.0             0.0
# 7        1.000000   28.000000            8.0            3.0             0.0
# 8      -65.000000   91.126933            6.0            3.0             0.0
# 9      -33.000000   91.126933            3.0            3.0             0.0
# 10     -94.000000  238.000000            1.0            3.0             0.0
# ...

# %%
df_new=df_exp[df_exp['is_goal'].notnull()]

# %%
df_new
# Out:
#        location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 1     -157.000000    0.000000           10.0            1.0             0.0
# 2     -101.000000  135.000000            7.0            1.0             0.0
# 3      138.000000  175.000000            6.0            1.0             0.0
# 4        0.000000    0.000000            5.0            2.0             0.0
# 5     -145.000000  -11.000000            9.0            3.0             0.0
# 6        0.000000    0.000000            8.0            3.0             0.0
# 8      -65.000000   91.126933            6.0            3.0             0.0
# 9      -33.000000   91.126933            3.0            3.0             0.0
# 10     -94.000000  238.000000            1.0            3.0             0.0
# 11     121.000000  127.000000           11.0            1.0             0.0
# 12     -67.000000   91.126933            7.0            1.0             0.0
# ...

# %%
df_test=df_exp[df_exp['is_goal'].isnull()]

# %%
xpd=pd.DataFrame(x)
xpd
# Out:
#              0         1         2         3         4         5         6   \
# 0     -1.530316 -1.066193  1.519414 -1.368353 -0.400928 -0.367946  0.167894
# 1     -1.009322  0.507839  0.627896 -1.368353 -0.400928  0.980709  0.277359
# 2      1.214204  0.974219  0.330723 -1.368353 -0.400928  1.391169  0.934144
# 3     -0.069673 -1.066193  0.033550 -0.482692 -0.400928 -0.543857 -1.474069
# 4     -1.418674 -1.194447  1.222241  0.402968 -0.400928  0.218426  0.058430
# 5     -0.069673 -1.066193  0.925069  0.402968 -0.400928  1.391169 -1.474069
# 6     -0.674398 -0.003699  0.330723  0.402968 -0.400928 -0.954317 -0.160498
# 7     -0.376687 -0.003699 -0.560795  0.402968 -0.400928  0.452974 -0.160498
# 8     -0.944198  1.708767 -1.155141  0.402968 -0.400928  1.625717  1.262537
# 9      1.056045  0.414563  1.816587 -1.368353 -0.400928 -1.657963  0.386823
# 10    -0.693005 -0.003699  0.627896 -1.368353 -0.400928 -0.016123 -0.001897
# ...

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]
test=df_test.iloc[:,:-1]
from sklearn.preprocessing import StandardScaler
sx=StandardScaler()
x=sx.fit_transform(x)
test=sx.transform(test)
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\rahul\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   import sys

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
regressor=LogisticRegression()
regressor.fit(x_train,y_train)
print(regressor.score(x_test,y_test))
# Out:
# 0.5920998772001638
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.svm import SVC
regressor=SVC(probability=True)
regressor.fit(x_train,y_train)
print(regressor.score(x_test,y_test))
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.5906672124437168

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
classifier.score(x_test,y_test)
# Out:
# 0.5540319279574294

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu',input_dim=14),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1,activation='sigmoid')
])
model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics=['accuracy'])
model.fit(x_train, y_train, batch_size = 16, nb_epoch = 100,validation_data=[x_test,y_test])
# Out:
# W0720 01:05:32.443310  7772 training.py:593] The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 19543 samples, validate on 4886 samples
# Epoch 1/100
# 19543/19543 [==============================] - 2s 112us/sample - loss: 0.6654 - acc: 0.5972 - val_loss: 0.6661 - val_acc: 0.5835
# Epoch 2/100
# 19543/19543 [==============================] - 2s 106us/sample - loss: 0.6577 - acc: 0.6062 - val_loss: 0.6669 - val_acc: 0.5870
# Epoch 3/100
# 19543/19543 [==============================] - 2s 113us/sample - loss: 0.6555 - acc: 0.6101 - val_loss: 0.6630 - val_acc: 0.5917
# Epoch 4/100
# 19543/19543 [==============================] - 2s 106us/sample - loss: 0.6534 - acc: 0.6115 - val_loss: 0.6623 - val_acc: 0.5876
# Epoch 5/100
# 19543/19543 [==============================] - 2s 121us/sample - loss: 0.6512 - acc: 0.6134 - val_loss: 0.6647 - val_acc: 0.5843
# Epoch 6/100
# ...

# %%
#df_test=sx.transform(df_test)
#df_test=df_test.iloc[:,:-1]

# %%
ypred=regressor.predict_proba(test)

# %%
ypred=ypred[:,1]

# %%
df_test.index.values
# Out:
# array([    0,     7,    16,    19,    21,    32,    33,    34,    35,
#           36,    37,    44,    49,    54,    59,    61,    65,    66,
#           70,    71,    75,    79,    84,    85,    86,    91,    94,
#           96,   103,   112,   121,   122,   125,   132,   133,   140,
#          143,   149,   151,   152,   155,   158,   164,   171,   181,
#          191,   192,   195,   201,   204,   209,   210,   227,   249,
#          256,   259,   261,   263,   266,   278,   281,   292,   298,
#          299,   300,   316,   326,   327,   334,   345,   347,   359,
#          364,   378,   381,   389,   390,   391,   396,   416,   417,
#          419,   427,   428,   433,   438,   439,   450,   455,   458,
#          471,   479,   490,   496,   508,   510,   522,   532,   543,
#          545,   551,   554,   557,   559,   567,   570,   572,   575,
#          577,   590,   595,   596,   600,   604,   616,   624,   627,
# ...

# %%
ypred=pd.DataFrame(ypred)

# %%
ypred['shot_id_number']=df_test.index.values

# %%
ypred.columns=['is_goal','shot_id_number']

# %%
ypred=ypred[['shot_id_number','is_goal']]

# %%
ypred.to_csv('submission.csv',index=False)
